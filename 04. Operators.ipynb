# %% [markdown]
# # 4. Operators
#
# Operators are of four types
# 1. Arithmetic Operator
# 2. Assignment Operator
# 3. Relational/Comparison Operator
# 4. Logical Operator

# %% [markdown]
# ## 4.1 Arithmetic Operators

# %% [markdown]
# | Operation | Symbol | Function |
# |----|---|---|
# | Addition | + |  |
# | Subtraction | - |   |
# | Multiplication | * |   |
# | Division | / |   |
# | Mod | % | Gives the reminder  |
# | to the power of | ** |   |
# | Floor Division | // |   |

# %% [markdown]
# ### 4.1.1 Arithmetic Operations on integers

# %%
age = 51

# %%
age+age
# Out:
# 102

# %%
age*2
# Out:
# 102

# %%
age/2
# Out:
# 25.5

# %%
age%2
# Out:
# 1

# %% [markdown]
# ### 4.1.2 Arithmetic Operations on Float

# %%
weight = 21

# %%
weight/2
# Out:
# 10.5

# %%
weight%3
# Out:
# 0

# %%
weight//4
# Out:
# 5

# %%
weight**2
# Out:
# 441

# %%
weight == 34
# Out:
# False

# %% [markdown]
# ### 4.1.3 Arithmetic Operations on  String

# %%
player_name = "Alice"

# %%
"player_name" + " in wonderland" # observe the space given
# Out:
# 'player_name in wonderland'

# %%
player_name*2   # its nothing but writing 2 times
# Out:
# 'AliceAlice'

# %%
player_name/2   # Dividing any string by a number is meaningless
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d945bd8dc7cf> in <module>
# ----> 1 player_name/2   # Dividing any string by a number is meaningless
#
# NameError: name 'player_name' is not defined

# %%
player_name == 'Alice'
# Out:
# True

# %%
player_name == 'Mary'
# Out:
# False

# %%
player_name>'a'
# Out:
# False

# %% [markdown]
# ## 4.2 Assignment Operators

# %% [markdown]
# ![assignment.JPG](attachment:assignment.JPG)

# %%
k=34
k+=12
k=-12
k/=12
print(k)
# Out:
# -1.0

# %% [markdown]
# ## 4.3 Relational or Comparison Operators

# %% [markdown]
# | Symbol | Task Performed |
# |----|---|
# | == | True, if it is equal |
# | !=  | True, if not equal to |
# | < | less than |
# | > | greater than |
# | <=  | less than or equal to |
# | >=  | greater than or equal to |
#
# We endup getting boolean variable as output

# %%
u=(1>2)
print(u)
# Out:
# False

# %%
v=(5>3)
print(v)
# Out:
# True

# %%
w=(78!=90)
print(w)
# Out:
# True

# %%
# Unicode of the correspondings characters
print(ord('A'))
print(ord('a'))
# Out:
# 65
# 97

# %% [markdown]
# ## 4.4 Logical Operators
#
# In Python, Logical operators are used on conditional statements (either True or False). They perform Logical AND, Logical OR and Logical NOT operations.

# %% [markdown]
# ![logical.JPG](attachment:logical.JPG)

# %% [markdown]
# ### 4.4.1 Logical AND operator
# Logical operator returns True if both the operands are True else it returns False.

# %%
# Python program to demonstrate logical AND operator

a = 10
b = 10
c = -10

if a > 0 and b > 0:
  print("The numbers are greater than 0")

if a > 0 and b > 0 and c > 0:
  print("The numbers are greater than 0")
else:
  print("Atleast one number is not greater than 0")
# Out:
# The numbers are greater than 0
# Atleast one number is not greater than 0

# %%
# Python program to demonstrate logical AND operator

a = 10
b = 12
c = 0

if a and b and c:
  print("All the numbers have boolean value as True")
else:
  print("Atleast one number has boolean value as False")
# Out:
# Atleast one number has boolean value as False

# %% [markdown]
# ### 4.4.3 Logical OR operator
# Logical or operator returns True if either of the operands is True.

# %%
# Python program to demonstrate logical OR operator

a = 10
b = -10
c = 0

if a > 0 or b > 0:
  print("Either of the number is greater than 0")
else:
  print("No number is greater than 0")

if b > 0 or c > 0:
  print("Either of the number is greater than 0")
else:
  print("No number is greater than 0")
# Out:
# Either of the number is greater than 0
# No number is greater than 0

# %% [markdown]
# ### 4.4.2 Logical NOT operator
# Logical not operator work with the single boolean value. If the boolean value is True it returns False and vice-versa.

# %%
# Python program to demonstrate logical NOT operator

a = 10

if not a:
  print("Boolean value of a is True")

if not (a%3 == 0 or a%5 == 0):
  print("10 is not divisible by either 3 or 5")
else:
  print("10 is divisible by either 3 or 5")
# Out:
# 10 is divisible by either 3 or 5
